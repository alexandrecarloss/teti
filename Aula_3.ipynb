# %%
import pandas as pd
import seaborn as sns

# %%
path = 'D:/Salve_Aqui_Seus_Arquivos/Carlos Alexandre/2024-2/teti/'

# %%
df_mkt = pd.read_csv(path + 'dados_marketing.csv')

# %%
df_mkt.head()
# Out:
#          Data  Semana  Semana_ID  Mes  Mes_ID   Ano Nome_Dia  Visitantes  \
# 0  09/11/2020      46         34   11      11  2020  Segunda         707
# 1  10/11/2020      46         34   11      11  2020    Terça        1455
# 2  11/11/2020      46         34   11      11  2020   Quarta        1520
# 3  12/11/2020      46         34   11      11  2020   Quinta        1726
# 4  13/11/2020      46         34   11      11  2020    Sexta        2134
#
#    Vendas  Gastos_Mkt           Promo
# 0     465     651.375         Nenhuma
# 1   10386    1298.250  Promo Vermelha
# 2   12475    1559.375      Promo Azul
# 3   11712    1801.750         Nenhuma
# 4   10000    2614.500         Nenhuma

# %%
df_mkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data        182 non-null    object
#  1   Semana      182 non-null    int64
#  2   Semana_ID   182 non-null    int64
#  3   Mes         182 non-null    int64
#  4   Mes_ID      182 non-null    int64
#  5   Ano         182 non-null    int64
#  6   Nome_Dia    182 non-null    object
#  7   Visitantes  182 non-null    int64
#  8   Vendas      182 non-null    int64
#  9   Gastos_Mkt  182 non-null    float64
#  10  Promo       182 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 15.8+ KB

# %%
df_mkt.describe()
# Out:
#            Semana   Semana_ID         Mes      Mes_ID          Ano  \
# count  182.000000  182.000000  182.000000  182.000000   182.000000
# mean    21.785714   47.351648    5.269231   13.774725  2020.708791
# std     18.369841    7.892053    4.204580    1.783540     0.455573
# min      1.000000   34.000000    1.000000   11.000000  2020.000000
# 25%      8.000000   40.000000    2.000000   12.000000  2020.000000
# 50%     14.000000   48.000000    4.000000   14.000000  2021.000000
# 75%     47.000000   54.000000   11.000000   15.000000  2021.000000
# max     53.000000   61.000000   12.000000   17.000000  2021.000000
#
#         Visitantes        Vendas   Gastos_Mkt
# count   182.000000    182.000000   182.000000
# mean   1666.730769  10581.593407  1396.356564
# std     503.528049   6297.626426   691.867416
# min     488.000000    292.000000   322.000000
# 25%    1339.000000   5929.500000   880.431250
# 50%    1546.000000   9452.000000  1223.900000
# 75%    2027.500000  12959.500000  1676.450000
# max    4139.000000  36283.000000  4535.375000

# %%
df_mkt.groupby('Promo').sum('Gastos_Mkt').sort_values('Gastos_Mkt', ascending=False)
# Out:
#                 Semana  Semana_ID  Mes  Mes_ID     Ano  Visitantes  Vendas  \
# Promo
# Promo Azul        1177       2543  285     741  109118       96709  902101
# Nenhuma           1582       3503  384    1020  149533      120446  438415
# Promo Vermelha    1206       2572  290     746  109118       86190  585334
#
#                   Gastos_Mkt
# Promo
# Promo Azul      98805.496969
# Nenhuma         87073.155555
# Promo Vermelha  68258.242173

# %%
df_mkt_1 = df_mkt.groupby('Promo').sum('Gastos_Mkt').sort_values('Gastos_Mkt', ascending=False)

# %%
df_mkt_1[['Semana', 'Ano', 'Visitantes']]
# Out:
#                 Semana     Ano  Visitantes
# Promo
# Promo Azul        1177  109118       96709
# Nenhuma           1582  149533      120446
# Promo Vermelha    1206  109118       86190

# %%
df_mkt.groupby('Mes').sum('Visitantes').sort_values('Visitantes', ascending=False)
# Out:
#      Semana  Semana_ID  Mes_ID    Ano  Visitantes  Vendas    Gastos_Mkt
# Mes
# 12     1581       1209     372  62620       54842  361702  46781.242426
# 1       106       1377     403  62651       52694  297244  42243.294949
# 3       368       1639     465  62651       51373  327216  42584.533334
# 4       486       1716     480  60630       49105  324195  41043.729041
# 2       214       1362     392  56588       45449  299149  36073.774242
# 11     1039        775     242  44440       35092  247620  33901.538382
# 5       171        540     153  18189       14790   68724  11508.782324

# %%
lin = sns.lineplot(x = 'Semana_ID', y = 'Vendas', data=df_mkt)

# %%
lin = sns.lineplot(x = 'Semana_ID', y = 'Vendas', hue = 'Promo', data=df_mkt)

# %%
lin = sns.lineplot(x = 'Semana_ID', y = 'Vendas', \
hue = 'Promo', data=df_mkt, errorbar=None)

# %% [markdown]
# Barplot

# %%
bar = sns.barplot(x = 'Mes_ID', y = 'Vendas', data=df_mkt)
