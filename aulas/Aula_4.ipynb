# %%
import pandas as pd
import seaborn as sns

# %%
path = 'D:/Salve_Aqui_Seus_Arquivos/Carlos Alexandre/2024-2/teti/'

# %%
df_mun = pd.read_csv(path + 'municipios_2.csv', sep=';')
df_est = pd.read_csv(path + 'estados.csv')
df_lon = pd.read_csv(path + 'london.csv')

# %%
df_est.head()
# Out:
#    codigo_uf  uf      nome
# 0         11  RO  Rondônia
# 1         12  AC      Acre
# 2         13  AM  Amazonas
# 3         14  RR   Roraima
# 4         15  PA      Pará

# %%
df_mun.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
df_lon.head()
# Out:
#    Total      Sport  Age  Height  Weight Sex
# 0      0       Judo   23   170.0    60.0   M
# 1      0  Athletics   33   193.0   125.0   M
# 2      0  Athletics   30   187.0    76.0   M
# 3      0     Boxing   24     NaN     NaN   M
# 4      0  Athletics   26   178.0    85.0   F

# %%
df_est.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   codigo_uf  27 non-null     int64
#  1   uf         27 non-null     object
#  2   nome       27 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 776.0+ bytes

# %%
df_mun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   codigo_ibge  5570 non-null   int64
#  1   nome         5570 non-null   object
#  2   latitude     5570 non-null   float64
#  3   longitude    5570 non-null   float64
#  4   capital      5570 non-null   int64
#  5   codigo_uf    5570 non-null   int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 261.2+ KB

# %%
df_lon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10384 entries, 0 to 10383
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   10384 non-null  int64
#  1   Sport   10384 non-null  object
#  2   Age     10384 non-null  int64
#  3   Height  9823 non-null   float64
#  4   Weight  9104 non-null   float64
#  5   Sex     10384 non-null  object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 486.9+ KB

# %%
df_est.describe()
# Out:
#        codigo_uf
# count  27.000000
# mean   29.111111
# std    13.024631
# min    11.000000
# 25%    19.000000
# 50%    27.000000
# 75%    38.000000
# max    53.000000

# %%
df_mun.describe()
# Out:
#         codigo_ibge     latitude    longitude      capital    codigo_uf
# count  5.570000e+03  5570.000000  5570.000000  5570.000000  5570.000000
# mean   3.253591e+06   -16.449144   -46.231003     0.004847    32.377738
# std    9.849103e+05     8.287237     6.408539     0.069461     9.833862
# min    1.100015e+06   -33.686600   -72.899700     0.000000    11.000000
# 25%    2.512126e+06   -22.843875   -50.878525     0.000000    25.000000
# 50%    3.146280e+06   -18.094300   -46.523200     0.000000    31.000000
# 75%    4.119190e+06    -8.496445   -41.410775     0.000000    41.000000
# max    5.300108e+06     4.603140   -32.410700     1.000000    53.000000

# %%
df_lon.describe()
# Out:
#               Total           Age       Height       Weight
# count  10384.000000  10384.000000  9823.000000  9104.000000
# mean       0.052196     26.068856   176.907869    72.852812
# std        0.250149      5.440561    11.295433    16.067462
# min        0.000000     13.000000   132.000000    36.000000
# 25%        0.000000     22.000000   169.000000    61.000000
# 50%        0.000000     25.000000   177.000000    70.000000
# 75%        0.000000     29.000000   185.000000    81.000000
# max        5.000000     71.000000   221.000000   218.000000

# %%
df_est.shape
# Out:
# (27, 3)

# %%
df_mun.shape
# Out:
# (5570, 6)

# %%
df_lon.shape
# Out:
# (10384, 6)

# %%
pip install geopandas
# Out:
# ...
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# ...
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.2 MB 4.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.4/16.2 MB 7.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/16.2 MB 8.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/16.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.9/16.2 MB 9.2 MB/s eta 0:00:01
#    --------------------------- ------------ 11.0/16.2 MB 9.3 MB/s eta 0:00:01
#    ------------------------------- -------- 12.8/16.2 MB 9.3 MB/s eta 0:00:01
#    ------------------------------------ --- 14.9/16.2 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.2 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 8.5 MB/s eta 0:00:00
# ...

# %%
df_mun.query("capital == 1")
# Out:
#       codigo_ibge            nome   latitude  longitude  capital  codigo_uf
# 294       2800308         Aracaju -10.909100   -37.0677        1         28
# 580       1501402           Belém  -1.455400   -48.4898        1         15
# 592       3106200  Belo Horizonte -19.910200   -43.9266        1         31
# 642       1400100       Boa Vista   2.823840   -60.6753        1         14
# 755       5300108        Brasília -15.779500   -47.9297        1         53
# 972       5002704    Campo Grande -20.448600   -54.6295        1         50
# 1491      5103403          Cuiabá -15.601000   -56.0974        1         51
# 1508      4106902        Curitiba -25.419500   -49.2646        1         41
# 1812      4205407   Florianópolis -27.594500   -48.5477        1         42
# 1831      2304400       Fortaleza  -3.716640   -38.5423        1         23
# 1927      5208707         Goiânia -16.686400   -49.2643        1         52
# ...

# %%
df_mun.query("codigo_uf == 13")
# Out:
#       codigo_ibge         nome  latitude  longitude  capital  codigo_uf
# 170       1300029     Alvarães  -3.22727   -64.8007        0         13
# 195       1300060      Amaturá  -3.37455   -68.2005        0         13
# 216       1300086        Anamã  -3.56697   -61.3963        0         13
# 252       1300102        Anori  -3.74603   -61.6575        0         13
# 286       1300144         Apuí  -7.19409   -59.8960        0         13
# ...           ...          ...       ...        ...      ...        ...
# 5188      1304203         Tefé  -3.36822   -64.7193        0         13
# 5259      1304237    Tonantins  -2.86582   -67.7919        0         13
# 5345      1304260       Uarini  -2.99609   -65.1133        0         13
# 5400      1304302      Urucará  -2.52936   -57.7538        0         13
# 5404      1304401  Urucurituba  -3.12841   -58.1496        0         13
#
# [62 rows x 6 columns]

# %% [markdown]
# Loc

# %%
df_mun.loc[0:10, ["nome", "codigo_ibge"]]
# Out:
#                    nome  codigo_ibge
# 0       Abadia de Goiás      5200050
# 1   Abadia dos Dourados      3100104
# 2             Abadiânia      5200100
# 3                Abaeté      3100203
# 4            Abaetetuba      1500107
# 5               Abaiara      2300101
# 6                Abaíra      2900108
# 7                 Abaré      2900207
# 8                Abatiá      4100103
# 9         Abdon Batista      4200051
# 10      Abel Figueiredo      1500131

# %%
df_mun.query("nome == 'Manaus'")
# Out:
#       codigo_ibge    nome  latitude  longitude  capital  codigo_uf
# 2885      1302603  Manaus  -3.11866   -60.0212        1         13

# %%
df_mun.query("nome == 'Xique-Xique'")
# Out:
#       codigo_ibge         nome  latitude  longitude  capital  codigo_uf
# 5565      2933604  Xique-Xique   -10.823   -42.7245        0         29

# %%
df_mun.loc[4500:4540]
# Out:
#       codigo_ibge                       nome  latitude  longitude  capital  \
# 4500      3158409      Santana de Cataguases -21.28930   -42.5524        0
# 4501      2513505       Santana de Mangueira  -7.54705   -38.3236        0
# 4502      3547304        Santana de Parnaíba -23.44390   -46.9178        0
# 4503      3158508        Santana de Pirapama -18.99620   -44.0409        0
# 4504      2312007          Santana do Acaraú  -3.46144   -40.2118        0
# 4505      1506708        Santana do Araguaia  -9.32810   -50.3500        0
# 4506      2312106          Santana do Cariri  -7.17613   -39.7302        0
# 4507      3158607         Santana do Deserto -21.95120   -43.1583        0
# 4508      3158706        Santana do Garambéu -21.59830   -44.1050        0
# 4509      2708006         Santana do Ipanema  -9.36999   -37.2480        0
# 4510      4124004         Santana do Itararé -23.75870   -49.6293        0
# ...

# %%
df_mun.loc[[2881, 2883, 2885, 2897]]
# Out:
#       codigo_ibge        nome  latitude  longitude  capital  codigo_uf
# 2881      1302504  Manacapuru  -3.29066   -60.6216        0         13
# 2883      1302553   Manaquiri  -3.44078   -60.4612        0         13
# 2885      1302603      Manaus  -3.11866   -60.0212        1         13
# 2897      1302702    Manicoré  -5.80462   -61.2895        0         13

# %%
df_mun.query("codigo_uf == 25 & capital == 1")
# Out:
#       codigo_ibge         nome  latitude  longitude  capital  codigo_uf
# 2595      2507507  João Pessoa  -7.11509   -34.8641        1         25

# %%
df_mun[(df_mun['codigo_uf'] ==23)& (df_mun['capital']==1)]
# Out:
#       codigo_ibge       nome  latitude  longitude  capital  codigo_uf
# 1831      2304400  Fortaleza  -3.71664   -38.5423        1         23

# %%
df_mun.codigo_uf.value_counts()
# Out:
# codigo_uf
# 31    853
# 35    645
# 43    497
# 29    417
# 41    399
# 42    295
# 52    246
# 22    224
# 25    223
# 21    217
# 26    185
# 23    184
# 24    167
# 15    144
# 51    141
# 17    139
# 27    102
# 33     92
# 50     79
# 32     78
# 28     75
# 13     62
# 11     52
# 12     22
# 16     16
# 14     15
# 53      1
# Name: count, dtype: int64

# %% [markdown]
# Loc

# %%
df_mun.groupby('codigo_uf').size()
# Out:
# codigo_uf
# 11     52
# 12     22
# 13     62
# 14     15
# 15    144
# 16     16
# 17    139
# 21    217
# 22    224
# 23    184
# 24    167
# 25    223
# 26    185
# 27    102
# 28     75
# 29    417
# 31    853
# 32     78
# 33     92
# 35    645
# 41    399
# 42    295
# 43    497
# 50     79
# 51    141
# 52    246
# 53      1
# dtype: int64

# %%
df_mun2 = df_mun.set_index("nome")

# %%
df_mun2.head()
# Out:
#                      codigo_ibge  latitude  longitude  capital  codigo_uf
# nome
# Abadia de Goiás          5200050 -16.75730   -49.4412        0         52
# Abadia dos Dourados      3100104 -18.48310   -47.3916        0         31
# Abadiânia                5200100 -16.19700   -48.7057        0         52
# Abaeté                   3100203 -19.15510   -45.4444        0         31
# Abaetetuba               1500107  -1.72183   -48.8788        0         15

# %%
df_mun2.loc["Manaus"]
# Out:
# codigo_ibge    1.302603e+06
# latitude      -3.118660e+00
# longitude     -6.002120e+01
# capital        1.000000e+00
# codigo_uf      1.300000e+01
# Name: Manaus, dtype: float64

# %%
df_mun2.loc[["Manaus", "Itacoatiara", "Parintins", "Presidente Figueiredo"]]
# Out:
#                        codigo_ibge  latitude  longitude  capital  codigo_uf
# nome
# Manaus                     1302603  -3.11866   -60.0212        1         13
# Itacoatiara                1301902  -3.13861   -58.4449        0         13
# Parintins                  1303403  -2.63741   -56.7290        0         13
# Presidente Figueiredo      1303536  -2.02981   -60.0234        0         13

# %%
df_mun2.loc[df_mun2.latitude > 0]
# Out:
#                          codigo_ibge  latitude  longitude  capital  codigo_uf
# nome
# Alto Alegre                  1400050  2.988580   -61.3072        0         14
# Amajari                      1400027  3.645710   -61.3692        0         14
# Amapá                        1600105  2.052670   -50.7957        0         16
# Boa Vista                    1400100  2.823840   -60.6753        1         14
# Bonfim                       1400159  3.361610   -59.8333        0         14
# Calçoene                     1600204  2.504750   -50.9512        0         16
# Cantá                        1400175  2.609940   -60.6058        0         14
# Caracaraí                    1400209  1.827660   -61.1304        0         14
# Caroebe                      1400233  0.884203   -59.6959        0         14
# Cutias                       1600212  0.970761   -50.8005        0         16
# Ferreira Gomes               1600238  0.857256   -51.1795        0         16
# ...

# %% [markdown]
# iLoc

# %%
df_mun.iloc[1]
# Out:
# codigo_ibge                3100104
# nome           Abadia dos Dourados
# latitude                  -18.4831
# longitude                 -47.3916
# capital                          0
# codigo_uf                       31
# Name: 1, dtype: object

# %%
df_mun.iloc[0:10, 0:2]
# Out:
#    codigo_ibge                 nome
# 0      5200050      Abadia de Goiás
# 1      3100104  Abadia dos Dourados
# 2      5200100            Abadiânia
# 3      3100203               Abaeté
# 4      1500107           Abaetetuba
# 5      2300101              Abaiara
# 6      2900108               Abaíra
# 7      2900207                Abaré
# 8      4100103               Abatiá
# 9      4200051        Abdon Batista

# %%
df_mun['latitude'].hist()
# Out:
# <Axes: >

# %%
df_est.head()
# Out:
#    codigo_uf  uf      nome
# 0         11  RO  Rondônia
# 1         12  AC      Acre
# 2         13  AM  Amazonas
# 3         14  RR   Roraima
# 4         15  PA      Pará

# %%
df_mun.merge(df_est, how='inner', on='codigo_uf')
# Out:
#       codigo_ibge               nome_x  latitude  longitude  capital  \
# 0         5200050      Abadia de Goiás -16.75730   -49.4412        0
# 1         3100104  Abadia dos Dourados -18.48310   -47.3916        0
# 2         5200100            Abadiânia -16.19700   -48.7057        0
# 3         3100203               Abaeté -19.15510   -45.4444        0
# 4         1500107           Abaetetuba  -1.72183   -48.8788        0
# ...           ...                  ...       ...        ...      ...
# 5565      2933604          Xique-Xique -10.82300   -42.7245        0
# 5566      2517407               Zabelê  -8.07901   -37.1057        0
# 5567      3557154             Zacarias -21.05060   -50.0552        0
# 5568      2114007              Zé Doca  -3.27014   -45.6553        0
# 5569      4219853               Zortéa -27.45210   -51.5520        0
#
#       codigo_uf  uf          nome_y
# 0            52  GO           Goiás
# 1            31  MG    Minas Gerais
# ...

# %%
df_mun.merge?
# Out:
# Signature:
# df_mun.merge(
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_on: 'IndexLabel | AnyArrayLike | None' = None,
#     right_on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'MergeValidate | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    ------------- -------------------------- 1.3/3.8 MB 7.4 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.8 MB 7.4 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.8 MB 7.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.8 MB 1.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.6/3.8 MB 1.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.1/3.8 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 2.6/3.8 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 2.0 MB/s eta 0:00:00
# ...

# %%
df_tambam = pd.read_html('https://en.wikipedia.org/wiki/Amazonas_(Brazilian_state)')

# %%
df_tambam
# Out:
# [          Year        Pop.          ±%
#  0         1872       57610           —
#  1         1890      147915     +156.8%
#  2         1900      249756      +68.9%
#  3         1920      363166      +45.4%
#  4         1940      438008      +20.6%
#  5         1950      514099      +17.4%
#  6         1960      721215      +40.3%
#  7         1970      960934      +33.2%
#  8         1980     1449135      +50.8%
#  9         1991     2102901      +45.1%
#  10        2000     2817252      +34.0%
#  11        2010     3483985      +23.7%
#  12        2022     3941613      +13.1%
#  13  Source:[1]  Source:[1]  Source:[1]]

# %%
df_tambam = pd.read_html('https://en.wikipedia.org/wiki/Amazonas_(Brazilian_state)', \
                        match = 'Historical population')

# %%
df_tambam
# Out:
# [          Year        Pop.          ±%
#  0         1872       57610           —
#  1         1890      147915     +156.8%
#  2         1900      249756      +68.9%
#  3         1920      363166      +45.4%
#  4         1940      438008      +20.6%
#  5         1950      514099      +17.4%
#  6         1960      721215      +40.3%
#  7         1970      960934      +33.2%
#  8         1980     1449135      +50.8%
#  9         1991     2102901      +45.1%
#  10        2000     2817252      +34.0%
#  11        2010     3483985      +23.7%
#  12        2022     3941613      +13.1%
#  13  Source:[1]  Source:[1]  Source:[1]]

# %%
df_tambam[0]
# Out:
#           Year        Pop.          ±%
# 0         1872       57610           —
# 1         1890      147915     +156.8%
# 2         1900      249756      +68.9%
# 3         1920      363166      +45.4%
# 4         1940      438008      +20.6%
# 5         1950      514099      +17.4%
# 6         1960      721215      +40.3%
# 7         1970      960934      +33.2%
# 8         1980     1449135      +50.8%
# 9         1991     2102901      +45.1%
# 10        2000     2817252      +34.0%
# 11        2010     3483985      +23.7%
# 12        2022     3941613      +13.1%
# 13  Source:[1]  Source:[1]  Source:[1]

# %%
df_am = df_tambam[0]

# %%
df_am.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    14 non-null     object
#  1   Pop.    14 non-null     object
#  2   ±%      14 non-null     object
# dtypes: object(3)
# memory usage: 464.0+ bytes

# %%
df_am[:13]
# Out:
#     Year     Pop.       ±%
# 0   1872    57610        —
# 1   1890   147915  +156.8%
# 2   1900   249756   +68.9%
# 3   1920   363166   +45.4%
# 4   1940   438008   +20.6%
# 5   1950   514099   +17.4%
# 6   1960   721215   +40.3%
# 7   1970   960934   +33.2%
# 8   1980  1449135   +50.8%
# 9   1991  2102901   +45.1%
# 10  2000  2817252   +34.0%
# 11  2010  3483985   +23.7%
# 12  2022  3941613   +13.1%

# %%
df_am_pop = df_am.loc[:, ['Year', 'Pop.']]

# %%
df_am_pop['Year'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df_am_pop['Year'].astype('int')
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\teti2024\lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File D:\Salve_Aqui_Seus_Arquivos\Anaconda\envs\teti2024\lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
# ...
