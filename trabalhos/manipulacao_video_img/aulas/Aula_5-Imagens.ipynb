# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageOps
# %matplotlib inline

# %%
from pylab import *

# %%
path_img = 'D:/Salve_Aqui_Seus_Arquivos/Carlos_Alexandre/2024-2/teti/teti_imagens/'

# %%
im1 = array(Image.open(path_img + 'trees.jpg'))

# %%
im1
# Out:
# array([[[125, 193, 232],
#         [127, 195, 234],
#         [132, 200, 239],
#         ...,
#         [ 96, 175, 218],
#         [101, 180, 223],
#         [ 94, 173, 216]],
#
#        [[121, 189, 228],
#         [125, 193, 232],
#         [125, 193, 232],
#         ...,
#         [ 85, 164, 207],
#         [ 94, 173, 216],
#         [ 96, 175, 218]],
#
#        [[125, 193, 230],
#         [117, 185, 222],
#         [129, 197, 234],
#         ...,
#         [ 89, 170, 213],
#         [ 95, 174, 217],
#         [103, 182, 225]],
#
#        ...,
#
#        [[168, 120,  38],
#         [118,  71,   0],
#         [192, 147,  64],
#         ...,
#         [111,  84,  55],
#         [ 55,  31,   7],
#         [ 18,   0,   0]],
#
#        [[224, 175,  99],
#         [128,  80,   4],
#         [156, 110,  33],
#         ...,
#         [ 93,  68,  48],
#         [175, 154, 137],
#         [109,  90,  75]],
#
#        [[172, 123,  54],
#         [118,  69,   0],
#         [135,  88,  18],
# ...

# %%
imshow(im1)

# %%
im1.shape
# Out:
# (1017, 1882, 3)

# %%
def plot_2img(img1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1,2,1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,2,2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
def plot_3img(im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1,3,1), plt.imshow(im1, cmap = "gray"), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,3,2), plt.imshow(im2, cmap = "gray"), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,3,3), plt.imshow(im3, cmap = "gray"), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
im2 = array(Image.open(path_img + 'balao_montanhas_geladas.jpg'))

# %%
plot_2img(im1, 'Imagem1', im2, 'Imagem2', (12, 10))

# %%
im3 = array(Image.open(path_img + 'baleias_mar_gelo.jpg'))

# %%
plot_3img(im1, 'Imagem1', im2, 'Imagem2', im3, 'Imagem3', (12, 10))

# %%
im1_ = im1.ravel()

# %%
im1_
# Out:
# array([125, 193, 232, ...,  87,  70,  52], dtype=uint8)

# %%
im1_.shape
# Out:
# (5741982,)

# %%
plt.hist(im1_)
# Out:
# (array([ 466549.,  424025.,  363002.,  285137.,  383366.,  403156.,
#          395905.,  850799., 1574523.,  595520.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)

# %%
np.save('saida_img', im1)

# %%
pwd
# Out:
# 'D:\\Salve_Aqui_Seus_Arquivos\\Carlos_Alexandre\\2024-2\\teti'

# %%
im4 = np.load('saida_img.npy')

# %%
im1_r = im1[:, :, 0]
im1_g = im1[:, :, 1]
im1_b = im1[:, :, 2]

# %%
plot_3img(im1_r, 'R', im1_g, 'G', im1_b, 'B', (12, 10))

# %%
plot_2img(im1,'Original', im1_g, 'G', (12, 10))

# %%
def plot_2img_gray(img1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1,2,1), plt.imshow(im1, cmap = 'gray'), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,2,2), plt.imshow(im2, cmap = 'gray'), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
plot_2img_gray(im1, 'Original', im1_r, 'R', (12, 10))

# %% [markdown]
# Padrão de leitura do opencv: B G R

# %%
im5 = array(Image.open(path_img + 'objetos.jpg'))

# %%
im5 = cv2.ctvColor(im5, cv2.COLOR_RGB2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 im5 = cv2.ctvColor(im5, cv2.COLOR_RGB2RGB)
#
# AttributeError: module 'cv2' has no attribute 'ctvColor'

# %%
plt
