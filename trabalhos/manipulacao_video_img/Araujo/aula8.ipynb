# %% [markdown]
# ##aula 8

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
modelo = ResNet50(weights='imagenet')

# %%
path = "E:/visao_am/imagens/"
img = path+'tucano3.png'

# %% [markdown]
# # a

# %%
img = image.load_img(img, target_size=(224, 224))

# %%
img_p = image.img_to_array(img)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)

# %%
preds = modelo.predict(imp_p)
# Out:
# 1/1 [==============================] - 0s 77ms/step

# %%
print('Predição: ', decode_predictions(preds, top=5)[0])
# Out:
# Predição:  [('n01843383', 'toucan', 0.92958796), ('n01829413', 'hornbill', 0.054402035), ('n01828970', 'bee_eater', 0.00351861), ('n01820546', 'lorikeet', 0.0030587183), ('n01818515', 'macaw', 0.0013807489)]

# %% [markdown]
# ## Exercício

# %%
import tensorflow as tf
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
path2 ="C:/Users/IFAM_CMZL/Downloads/imgs/gatos/"

# %%
path3 ="E:/visao_am/imagens/"

# %%
img_ar = path3+"ariranha.jpg"
img_ar = image.load_img(img_ar, target_size=(528,528,3))

# %%
img_bj = path3+"beija-flor.jpg"
img_bj = image.load_img(img_bj, target_size=(528,528,3))

# %%
img_ele= path3+"elefante.jpg"
img_ele = image.load_img(img_ele, target_size=(528,528,3))

# %%
img_pap= path3+"papagaio.jpg"
img_pap = image.load_img(img_pap, target_size=(528,528,3))

# %%
modelo2 = DenseNet121(weights='imagenet')

# %%
img_gato = path+"gato5.jpg"
img_gato = image.load_img(img_gato, target_size=(528,528,3))

# %%
plt.imshow(img_gato)

# %%
plt.imshow(img_ar)

# %%
plt.imshow(img_ele)

# %%
plt.imshow(img_bj)

# %%
plt.imshow(img_pap)

# %%
img_p = image.img_to_array(img_gato)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)

# %%
preds2 = modelo2.predict(img_p)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
print('Predição: ', decode_predictions(preds2, top=5)[0])
# Out:
# Predição:  [('n02123394', 'Persian_cat', 0.7938223), ('n02123159', 'tiger_cat', 0.069005944), ('n02123045', 'tabby', 0.060021132), ('n02127052', 'lynx', 0.04362268), ('n02124075', 'Egyptian_cat', 0.00910028)]

# %%
img_p = image.img_to_array(img_ele)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)

# %%
preds2 = modelo2.predict(img_p)
# Out:
# 1/1 [==============================] - 0s 66ms/step

# %%
print('Predição: ', decode_predictions(preds2, top=5)[0])
# Out:
# Predição:  [('n02504458', 'African_elephant', 0.522479), ('n01871265', 'tusker', 0.35037562), ('n02504013', 'Indian_elephant', 0.09307407), ('n02109047', 'Great_Dane', 0.001762646), ('n02093647', 'Bedlington_terrier', 0.0012968257)]

# %%
img_p = image.img_to_array(img_bj)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)

# %%
preds2 = modelo2.predict(img_p)
# Out:
# 1/1 [==============================] - 0s 84ms/step

# %%
print('Predição: ', decode_predictions(preds2, top=5)[0])
# Out:
# Predição:  [('n01843065', 'jacamar', 0.6996068), ('n01833805', 'hummingbird', 0.29001638), ('n01828970', 'bee_eater', 0.0086472165), ('n01558993', 'robin', 0.00022716947), ('n01560419', 'bulbul', 0.00020590861)]

# %%
img_p = image.img_to_array(img_ar)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)

# %%
preds2 = modelo2.predict(img_p)
# Out:
# 1/1 [==============================] - 0s 72ms/step

# %%
print('Predição: ', decode_predictions(preds2, top=5)[0])
# Out:
# Predição:  [('n02077923', 'sea_lion', 0.5728614), ('n02444819', 'otter', 0.39191398), ('n02113978', 'Mexican_hairless', 0.015465072), ('n02442845', 'mink', 0.0067176167), ('n02363005', 'beaver', 0.0066857114)]

# %%
def prediz(img):
    img_p = image.img_to_array(img)
    img_p = np.expand_dims(img_p, axis=0)
    imp_p = preprocess_input(img_p)

    preds2 = modelo2.predict(img_p)
    print('Predição: ', decode_predictions(preds2, top=5)[0])

# %%
import tensorflow as tf
from tensorflow.keras.applications.nasnet import NASNetLarge, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
modelo3 = NASNetLarge(weights='imagenet')

# %%
img_p = image.img_to_array(img_bj)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)

# %%
preds3 = modelo2.predict(img_p)
# Out:
# 1/1 [==============================] - 0s 64ms/step

# %%
print('Predição: ', decode_predictions(preds3, top=5)[0])
# Out:
# Predição:  [('n01843065', 'jacamar', 0.52492785), ('n01833805', 'hummingbird', 0.4420588), ('n01828970', 'bee_eater', 0.027767858), ('n01558993', 'robin', 0.0014164437), ('n01560419', 'bulbul', 0.00076397206)]

# %%
img_p = image.img_to_array(img_ar)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)

# %%
preds3 = modelo2.predict(img_p)
# Out:
# 1/1 [==============================] - 0s 69ms/step

# %%
print('Predição: ', decode_predictions(preds3, top=5)[0])
# Out:
# Predição:  [('n02077923', 'sea_lion', 0.6683701), ('n02444819', 'otter', 0.29922134), ('n02113978', 'Mexican_hairless', 0.017168084), ('n02363005', 'beaver', 0.005587531), ('n02442845', 'mink', 0.0039538867)]

# %%
img_p = image.img_to_array(img_ele)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds3 = modelo2.predict(img_p)
print('Predição: ', decode_predictions(preds3, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 70ms/step
# Predição:  [('n02504458', 'African_elephant', 0.5497504), ('n01871265', 'tusker', 0.2819434), ('n02504013', 'Indian_elephant', 0.1456624), ('n02437312', 'Arabian_camel', 0.0015948379), ('n01704323', 'triceratops', 0.0012045213)]

# %%
img_p = image.img_to_array(img_bj)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds3 = modelo2.predict(img_p)
print('Predição: ', decode_predictions(preds3, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Predição:  [('n01843065', 'jacamar', 0.52492785), ('n01833805', 'hummingbird', 0.4420588), ('n01828970', 'bee_eater', 0.027767858), ('n01558993', 'robin', 0.0014164437), ('n01560419', 'bulbul', 0.00076397206)]

# %%
img_p = image.img_to_array(img_gato)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds3 = modelo2.predict(img_p)
print('Predição: ', decode_predictions(preds3, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 67ms/step
# Predição:  [('n04409515', 'tennis_ball', 0.97614753), ('n06359193', 'web_site', 0.015542765), ('n03637318', 'lampshade', 0.004957695), ('n03942813', 'ping-pong_ball', 0.0015465957), ('n03729826', 'matchstick', 0.0008081937)]

# %%
import tensorflow as tf
from tensorflow.keras.applications.efficientnet import EfficientNetB6, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
modelo4 = EfficientNetB6(weights='imagenet')

# %%
img_p = image.img_to_array(img_ar)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds4 = modelo4.predict(img_p)
print('Predição: ', decode_predictions(preds4, top=5)[0])
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predição:  [('n02444819', 'otter', 0.61254925), ('n02077923', 'sea_lion', 0.059215173), ('n02442845', 'mink', 0.03626112), ('n02441942', 'weasel', 0.030705545), ('n02443114', 'polecat', 0.0061651985)]

# %%
img_p = image.img_to_array(img_bj)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds4 = modelo4.predict(img_p)
print('Predição: ', decode_predictions(preds4, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 372ms/step
# Predição:  [('n01833805', 'hummingbird', 0.4048123), ('n01843065', 'jacamar', 0.33759394), ('n01828970', 'bee_eater', 0.012046913), ('n01560419', 'bulbul', 0.0028883542), ('n01601694', 'water_ouzel', 0.0020344383)]

# %%
img_p = image.img_to_array(img_gato)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds4 = modelo4.predict(img_p)
print('Predição: ', decode_predictions(preds4, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 347ms/step
# Predição:  [('n02123394', 'Persian_cat', 0.33858433), ('n02123045', 'tabby', 0.1816451), ('n02123159', 'tiger_cat', 0.09992082), ('n02127052', 'lynx', 0.048066117), ('n02124075', 'Egyptian_cat', 0.02045318)]

# %%
img_p = image.img_to_array(img_ele)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds4 = modelo4.predict(img_p)
print('Predição: ', decode_predictions(preds4, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 349ms/step
# Predição:  [('n01871265', 'tusker', 0.55254024), ('n02504013', 'Indian_elephant', 0.1805931), ('n02504458', 'African_elephant', 0.12437758), ('n01704323', 'triceratops', 0.00091685436), ('n02391049', 'zebra', 0.0005531154)]

# %%
img_p = image.img_to_array(img_pap)
img_p = np.expand_dims(img_p, axis=0)
imp_p = preprocess_input(img_p)
preds4 = modelo4.predict(img_p)
print('Predição: ', decode_predictions(preds4, top=5)[0])
# Out:
# 1/1 [==============================] - 1s 597ms/step
# Predição:  [('n01818515', 'macaw', 0.3568148), ('n01820546', 'lorikeet', 0.31855962), ('n01817953', 'African_grey', 0.016907027), ('n01819313', 'sulphur-crested_cockatoo', 0.01178406), ('n01843383', 'toucan', 0.003940234)]
