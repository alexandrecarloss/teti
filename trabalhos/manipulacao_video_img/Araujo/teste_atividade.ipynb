# %% [markdown]
# ## teste atividade

# %%
path = 'C:/Users/user/visao_am/imagens_visao_am/'

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
from pylab import *
import cv2
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

# %%
def plot_im2(im1, tit1, im2, tit2, tam):
    figure(figsize = tam)
    plt.subplot(1,2,1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,2,2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.show()

def plot_im3(im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1,3,1), plt.imshow(im1, cmap = "gray"), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,3,2), plt.imshow(im2, cmap = "gray"), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,3,3), plt.imshow(im3, cmap = "gray"), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show()

def plot_im3_(im1, tit1, im2, tit2, im3, tit3, tam):
    figure(figsize = tam)
    plt.subplot(1,3,1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,3,2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(1,3,3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    plt.show()

def plot_im4(im1, tit1, im2, tit2, im3, tit3, im4, tit4, tam, cmp = True):
    plt.figure(figsize=tam)
    plt.subplot(2, 2, 1), plt.imshow(im1), plt.title(tit1)
    plt.xticks([]), plt.yticks([])

    if cmp:
        plt.subplot(2, 2, 2), plt.imshow(im2, cmap = "gray"), plt.title(tit2)
    else:
        plt.subplot(2, 2, 2), plt.imshow(im2), plt.title(tit2)
    plt.xticks([]), plt.yticks([])
    
    if cmp:
        plt.subplot(2, 2, 3), plt.imshow(im3, cmap = "gray"), plt.title(tit3)
    else:
        plt.subplot(2, 2, 3), plt.imshow(im3), plt.title(tit3)
    plt.xticks([]), plt.yticks([])
    
    if cmp:
        plt.subplot(2, 2, 4), plt.imshow(im4, cmap = "gray"), plt.title(tit4)
    else:
        plt.subplot(2, 2, 4), plt.imshow(im4), plt.title(tit4)
    plt.xticks([]), plt.yticks([])
    plt.tight_layout()
    plt.show()

# %%
def retorna_faixa_cores(cor):
    faixas_hsv = {
        "green": ((36, 50, 50), (85, 255, 255)),
        "blue": ((90, 50, 50), (128, 255, 255)),
        "yellow": ((22, 50, 50), (38, 255, 255))
    }
    return faixas_hsv.get(cor.lower(), "Cor inválida")

# %%
cor_escolha = input("Escolha a cor(green ou blue):")
faixas_cor = retorna_faixa_cores(cor_escolha)
print(f"Utilize a faixa (hsv): {faixas_cor}")
# Out:
# Escolha a cor(green ou blue): blue
# Utilize a faixa (hsv): ((90, 50, 50), (128, 255, 255))

# %%
im_praia = cv2.imread(path +'arara_azul.jpg')

# %%
im_praiahsv = cv2.cvtColor(im_praia, cv2.COLOR_BGR2HSV)

# %%
limiar_claro = np.array([11, 50, 50])
limiar_escuro = np.array([25, 255, 255])

# %%
mask = cv2.inRange(im_praiahsv, limiar_claro, limiar_escuro)

# %%
saida = cv2.bitwise_and(im_praiahsv, im_praiahsv, mask = mask)

# %%
imshow(saida)

# %%
imshow(im_praia)

# %%
def escolhe_cor(cor, img):

    im_pa = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    if (cor=="a"):
        limiar_claro = np.array([22, 50, 50])
        limiar_escuro = np.array([38, 255, 255])
        mask = cv2.inRange(im_pa, limiar_claro, limiar_escuro)
        saida = cv2.bitwise_and(im_praiahsv, im_praiahsv, mask = mask)
        return imshow(saida)
    elif (cor=="v"):
        limiar_claro = np.array([36, 50, 50])
        limiar_escuro = np.array([85, 255, 255])
        mask = cv2.inRange(im_pa, limiar_claro, limiar_escuro)
        saida = cv2.bitwise_and(im_pa, im_pa, mask = mask)
        return imshow(saida)
    elif (cor=="r"):
        limiar_claro = np.array([160, 50, 50])
        limiar_escuro = np.array([170, 255, 255])
        mask = cv2.inRange(im_pa, limiar_claro, limiar_escuro)
        saida = cv2.bitwise_and(im_pa, im_pa, mask = mask)
        return imshow(saida)
    elif (cor=="l"):
        limiar_claro = np.array([11, 50, 50])
        limiar_escuro = np.array([25, 255, 255])
        mask = cv2.inRange(im_pa, limiar_claro, limiar_escuro)
        saida = cv2.bitwise_and(im_pa, im_pa, mask = mask)
        return imshow(saida)
    elif (cor=="b"):
        limiar_claro = np.array([90, 50, 50])
        limiar_escuro = np.array([128, 255, 255])
        mask = cv2.inRange(im_pa, limiar_claro, limiar_escuro)
        saida = cv2.bitwise_and(im_pa, im_pa, mask = mask)
        return imshow(saida)
    else:
        limiar_claro = np.array([90, 50, 50])
        limiar_escuro = np.array([128, 255, 255])
        mask = cv2.inRange(im_pa, limiar_claro, limiar_escuro)
        saida = cv2.bitwise_and(im_pa, im_pa, mask = mask)
        return imshow(saida)

# %%
def mostra(img,c):
    img_pa = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    mask = escolhe_cor(c)
    saida = cv2.bitwise_and(img_pa, img_pa, mask = mask)
    imshow(saida)

# %%
mostra(im_praia, 'v')

# %%
cap = cv2.VideoCapture(0)
cont = 1
if cap.isOpened():
    rval, frame = cap.read()
else:
    rval = False
while rval:
    rval, frame = cap.read()
    if frame is not None:
        cv2.imshow('Frame', frame)
        #cv2.imwrite(path2 + '/quadros/' + str(cont) + '.jpg', frame)
        cont+=1
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
        cap.release()
cv2.destroyAllWindows()
print('Finalizou  a geração dos frames.')
# Out:
# Finalizou  a geração dos frames.

# %%
video = path + 'video1.mp4'
video2 = path + 'video2.mp4'
video3 = path + 'mont_russa.mp4'

# %%
cap = cv2.VideoCapture(video3)
cont = 1
if cap.isOpened():
    rval, frame = cap.read()
else:
    rval = False
while rval:
    rval, frame = cap.read()
    if frame is not None:
        padrao = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
        mask = cv2.inRange(padrao, limiar_claro, limiar_escuro)
        saida = cv2.bitwise_and(padrao, padrao, mask = mask)
        cv2.imshow('Frame', saida)
        #cv2.imwrite(path2 + '/quadros/' + str(cont) + '.jpg', frame)
        cont+=1
        key = cv2.waitKey(1) & 0xFF
    if key == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
print('Finalizou  a geração dos frames.')
# Out:
# Finalizou  a geração dos frames.

# %%
escolhe_cor("r", im_praia)
